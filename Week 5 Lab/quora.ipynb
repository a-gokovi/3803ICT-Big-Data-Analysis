# %% [markdown]
# # Quora Insincere Questions Classification

# %% [markdown]
# ## Context
# Quora is a popular website where anyone can ask and/or answer a question. There are more than 100 millions unique visitors per month.
#
# Like any other forum, Quora is facing a problem: toxic questions and comments.
#
# As you can imagine, Quora teams cannot check all of the Q&A by hand. So they decided to ask the data science community to help them to perform automatically insincere questions classification.

# %% [markdown]
# ## Data
# This challenge was launched on Kaggle : https://www.kaggle.com/c/quora-insincere-questions-classification.
#
# Read the overall information on Kaggle. Quora provided a dataset of questions with a label, and the features are the following:
#
# + qid: a unique identifier for each question, an hexadecimal number
# + question_text: the text of the question
# + target: either 1 (for insincere question) or 0
#
# In this competition, the metric used for performance evaluation is the F-score.

# %% [markdown]
# ## EDA

# %%
import pandas as pd
import numpy as np
import os

#TODO: Read the training data in CSV file
df = pd.read_csv("train.csv")
df.shape
# Out:
# (1306122, 3)

# %%
#TODO: Check data
df.head()
# Out:
#                     qid                                      question_text  \
# 0  00002165364db923c7e6  How did Quebec nationalists see their province...
# 1  000032939017120e6e44  Do you have an adopted dog, how would you enco...
# 2  0000412ca6e4628ce2cf  Why does velocity affect time? Does velocity a...
# 3  000042bf85aa498cd78e  How did Otto von Guericke used the Magdeburg h...
# 4  0000455dfa3e01eae3af  Can I convert montra helicon D to a mountain b...
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# TODO: Print the class distribution 
toxic = df[df["target"]==1]["target"].count() / df.shape[0] * 100
nontoxic = df[df["target"]==0]["target"].count() / df.shape[0] * 100

print("Ratio of toxic question {} %".format(toxic))
print("Ratio of non toxic question {} %".format(nontoxic))
# Out:
# Ratio of toxic question 6.187017751787352 %
# Ratio of non toxic question 93.81298224821265 %

# %%
pd.set_option('display.max_colwidth', 1000)
df[df.target==1].head(n=10)
# Out:
#                       qid  \
# 22   0000e91571b60c2fb487
# 30   00013ceca3f624b09f42
# 110  0004a7fcb2bf73076489
# 114  00052793eaa287aff1e1
# 115  000537213b01fd77b58a
# 119  00056d45a1ce63856fc6
# 127  0005de07b07a17046e27
# 144  00068875d7c82a5bcf88
# 156  0006ffd99a6599ff35b3
# 167  00075f7061837807c69f
#
#                                                                                                                                                             question_text  \
# 22                                                                                                    Has the United States become the largest dictatorship in the world?
# 30                                                                                 Which babies are more sweeter to their parents? Dark skin babies or light skin babies?
# 110                                                                If blacks support school choice and mandatory sentencing for criminals why don't they vote Republican?
# 114                             I am gay boy and I love my cousin (boy). He is sexy, but I dont know what to do. He is hot, and I want to see his di**. What should I do?
# 115                                                                                                                                  Which races have the smallest penis?
# 119                                                                                                                                     Why do females find penises ugly?
# 127                                                                                           How do I marry an American woman for a Green Card? How much do they charge?
# 144                 Why do Europeans say they're the superior race, when in fact it took them over 2,000 years until mid 19th century to surpass China's largest economy?
# 156                                                                   Did Julius Caesar bring a tyrannosaurus rex on his campaigns to frighten the Celts into submission?
# 167  In what manner has Republican backing of 'states rights' been hypocritical and what ways have they actually restricted the ability of states to make their own laws?
#
#      target
# 22        1
# 30        1
# 110       1
# 114       1
# 115       1
# 119       1
# 127       1
# 144       1
# 156       1
# 167       1

# %% [markdown]
# The dataset is quite big, Let's play with a sample of 10000 lines.

# %%
from sklearn.utils import resample

#TODO: sample 10000 questions
df_sample = resample(df, n_samples = 10000)
df_sample.shape
# Out:
# (10000, 3)

# %% [markdown]
# Check the proportion of toxic question within our sample

# %%
#TODO

toxic = df_sample[df_sample["target"]==1]["target"].count() / df_sample.shape[0] * 100
nontoxic = df_sample[df_sample["target"]==0]["target"].count() / df_sample.shape[0] * 100


print("Ratio of toxic question {} %".format(toxic))
print("Ratio of non toxic question {} %".format(nontoxic))
# Out:
# Ratio of toxic question 5.82 %
# Ratio of non toxic question 94.17999999999999 %

# %% [markdown]
# ## Text Preprocessing

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", 
                       "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not",
                       "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", 
                       "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", 
                       "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", 
                       "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", 
                       "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", 
                       "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have",
                       "it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have",
                       "mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", 
                       "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                       "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", 
                       "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", 
                       "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                       "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would",
                       "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", 
                       "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", 
                       "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                       "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", 
                       "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", 
                       "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", 
                       "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", 
                       "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", 
                       "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", 
                       "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", 
                       "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are",
                       "y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                       "you'll've": "you will have", "you're": "you are", "you've": "you have" }

#TODO: normalize the text by using contraction mapping

for contraction in contraction_mapping:
    df_sample["question_text"] = df_sample["question_text"].apply(lambda x: str(x).replace(contraction, contraction_mapping[contraction]))

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

def text_preprocess(text):
    text = text.lower()
    #after checking vocab_out dict we decided to aply those following replace
    text = text.replace("-", " ").replace("/", " ").replace("\\", " ").replace("'", " ")
    tokens = word_tokenize(text)
    tokens = [t for t in tokens if t.isalpha()]
    return tokens

#TODO: you can further remove stop words and use lemmtizer
lemmatizer = WordNetLemmatizer()
stop_words = stopwords.words("english")

# %%
df_sample["tokens"] = df_sample["question_text"].apply(lambda x: text_preprocess(x))
df_sample.head()
# Out:
#                           qid  \
# 1306057  fffcc30ffad59abeb37c
# 1054851  ceb482134d2febdf1ca9
# 458916   59e38ecfecac0d30ff17
# 777189   983ba415e1b49aa501ef
# 106550   14df3cd54d22e3f7d989
#
#                                                                                                                  question_text  \
# 1306057                                                                                Can profanity make you have bad breath?
# 1054851                                                                       What is the scope of food microbiology in India?
# 458916                                                                                   What is the Maharashtrian Panchkarma?
# 777189                                                          What's the best alternative to Craigslist's casual encounters?
# 106550   Do left-leaning parties mostly win in the U.K. and the E.U. because of the voting rights extended to most immigrants?
#
#          target  \
# 1306057       0
# 1054851       0
# 458916        0
# 777189        0
# 106550        1
#
#                                                                                                                                  tokens
# 1306057                                                                                  [can, profanity, make, you, have, bad, breath]
# 1054851                                                                       [what, is, the, scope, of, food, microbiology, in, india]
# 458916                                                                                       [what, is, the, maharashtrian, panchkarma]
# 777189                                                         [what, s, the, best, alternative, to, craigslist, s, casual, encounters]
# 106550   [do, left, leaning, parties, mostly, win, in, the, and, the, because, of, the, voting, rights, extended, to, most, immigrants]

# %%
#TODO: you can further remove stop words and use lemmtizer
df_sample["tokens_no_stop"] = df_sample["tokens"].apply(lambda x : [word for word in x if word not in stop_words])
df_sample["lemmatized"] = df_sample["tokens_no_stop"].apply(lambda x : [lemmatizer.lemmatize(word) for word in x])
df_sample
# Out:
#                           qid  \
# 1306057  fffcc30ffad59abeb37c
# 1054851  ceb482134d2febdf1ca9
# 458916   59e38ecfecac0d30ff17
# 777189   983ba415e1b49aa501ef
# 106550   14df3cd54d22e3f7d989
# ...                       ...
# 1115727  daa2076beefd50f49dae
# 601322   75c7dbd950bf92b7583b
# 610079   7777d238611d8533815e
# 424017   531dbc157892ba1dec04
# 1241452  f3499d090339f1266315
#
#                                                                                                                       question_text  \
# 1306057                                                                                     Can profanity make you have bad breath?
# 1054851                                                                            What is the scope of food microbiology in India?
# 458916                                                                                        What is the Maharashtrian Panchkarma?
# 777189                                                               What's the best alternative to Craigslist's casual encounters?
# 106550        Do left-leaning parties mostly win in the U.K. and the E.U. because of the voting rights extended to most immigrants?
# ...                                                                                                                             ...
# 1115727                                                                                                What are pulses and lentils?
# 601322   Is "black girl magic" a way to make black women feel better about their plight and the way they are perceived by society ?
# 610079                                                    What are the best ways to get from Tallahassee, FL to Ft. Lauderdale, FL?
# 424017    Are there any essays about technology's penchant for shifting a person into multiple concurrent situations and realities?
# 1241452                                           Do you financially support members in your family solely because they are family?
#
#          target  \
# 1306057       0
# 1054851       0
# 458916        0
# 777189        0
# 106550        1
# ...         ...
# 1115727       0
# 601322        1
# 610079        0
# 424017        0
# 1241452       0
#
#                                                                                                                                                  tokens  \
# 1306057                                                                                                  [can, profanity, make, you, have, bad, breath]
# 1054851                                                                                       [what, is, the, scope, of, food, microbiology, in, india]
# 458916                                                                                                       [what, is, the, maharashtrian, panchkarma]
# 777189                                                                         [what, s, the, best, alternative, to, craigslist, s, casual, encounters]
# 106550                   [do, left, leaning, parties, mostly, win, in, the, and, the, because, of, the, voting, rights, extended, to, most, immigrants]
# ...                                                                                                                                                 ...
# 1115727                                                                                                               [what, are, pulses, and, lentils]
# 601322   [is, black, girl, magic, a, way, to, make, black, women, feel, better, about, their, plight, and, the, way, they, are, perceived, by, society]
# 610079                                                                 [what, are, the, best, ways, to, get, from, tallahassee, fl, to, lauderdale, fl]
# 424017      [are, there, any, essays, about, technology, s, penchant, for, shifting, a, person, into, multiple, concurrent, situations, and, realities]
# 1241452                                                  [do, you, financially, support, members, in, your, family, solely, because, they, are, family]
#
#                                                                                         tokens_no_stop  \
# 1306057                                                                 [profanity, make, bad, breath]
# 1054851                                                             [scope, food, microbiology, india]
# 458916                                                                     [maharashtrian, panchkarma]
# 777189                                             [best, alternative, craigslist, casual, encounters]
# 106550                     [left, leaning, parties, mostly, win, voting, rights, extended, immigrants]
# ...                                                                                                ...
# 1115727                                                                              [pulses, lentils]
# 601322    [black, girl, magic, way, make, black, women, feel, better, plight, way, perceived, society]
# 610079                                              [best, ways, get, tallahassee, fl, lauderdale, fl]
# 424017   [essays, technology, penchant, shifting, person, multiple, concurrent, situations, realities]
# 1241452                                        [financially, support, members, family, solely, family]
#
#                                                                                            lemmatized
# 1306057                                                                [profanity, make, bad, breath]
# 1054851                                                            [scope, food, microbiology, india]
# 458916                                                                    [maharashtrian, panchkarma]
# 777189                                             [best, alternative, craigslist, casual, encounter]
# 106550                        [left, leaning, party, mostly, win, voting, right, extended, immigrant]
# ...                                                                                               ...
# 1115727                                                                               [pulse, lentil]
# 601322   [black, girl, magic, way, make, black, woman, feel, better, plight, way, perceived, society]
# 610079                                              [best, way, get, tallahassee, fl, lauderdale, fl]
# 424017      [essay, technology, penchant, shifting, person, multiple, concurrent, situation, reality]
# 1241452                                        [financially, support, member, family, solely, family]
#
# [10000 rows x 6 columns]

# %% [markdown]
# ## Word Embeddings
#
# Should we preprocess the text with our classic methods... well not really ! First let's check what is the proportion of our document vocabulary that is taken into account by our embeddings.

# %%
import numpy as np

# Function that allows to read a pretrained model and returns words and a dictionary of word embeddings
def read_glove_vecs(glove_file):
    with open(glove_file, 'r', encoding = 'utf-8') as f:
        words = []
        word_to_vec_map = {}
        bad = 0
        
        for line in f:
            line = line.strip().split()
            curr_word = line[0]
            words.append(curr_word)
            try :
                word_to_vec_map[curr_word] = np.array(line[1:], dtype=np.float64)
            except ValueError:
                bad +=1
            
        print(f'There are {bad} bad lines')
    return words, word_to_vec_map

# %%
#TODO: Load Glove embedding
glove_file = "glove.6B.50d.txt"
words, word_to_vec_map = read_glove_vecs(glove_file)
# Out:
# There are 0 bad lines

# %%
import operator

#TODO: check if any token is not in the Glove embedding 

def is_in_vocab(tokens_list):
    in_vocab = {}
    out_vocab = {}
    for lst in tokens_list:
        for token in lst:
            if token.lower() in words:
                in_vocab[token]  = 1
            elif token in out_vocab.keys():
                out_vocab[token] += 1
            else:
                out_vocab[token] = 1

    out_vocab_ordered = sorted(out_vocab.items(), key=operator.itemgetter(1))[::-1]
    return in_vocab, out_vocab_ordered

# %%
text = np.array(df_sample.tokens)
in_vocab, out_vocab = is_in_vocab(text)

in_vocab_ratio = len(in_vocab.keys())/(len(in_vocab.keys()) + len(out_vocab))
out_vocab_ratio = len(out_vocab)/(len(in_vocab.keys()) + len(out_vocab))
                                                             
print("proportion of words in word embedding vocab: ", in_vocab_ratio*100, "%")
print("proportion of words not in word embedding vocab: ", out_vocab_ratio*100, "%")
# Out:
# proportion of words in word embedding vocab:  93.39843212763031 %
# proportion of words not in word embedding vocab:  6.601567872369688 %

# %%
len(out_vocab)
# Out:
# 960

# %%
out_vocab
# Out:
# [('bitsat', 6),
#  ('quorans', 6),
#  ('blockchain', 5),
#  ('cryptocurrencies', 4),
#  ('pdpu', 4),
#  ('iiser', 4),
#  ('upvotes', 4),
#  ('numericals', 3),
#  ('ntse', 3),
#  ('cryptocurrency', 3),
#  ('viteee', 3),
#  ('flipkart', 3),
#  ('passout', 3),
#  ('friendzone', 3),
#  ('ibps', 3),
#  ('redmi', 3),
#  ('chatbot', 3),
#  ('iisers', 3),
#  ('duolingo', 3),
#  ('ethereum', 3),
#  ('upvote', 3),
#  ('jiren', 3),
#  ('intjs', 2),
#  ('potterheads', 2),
#  ('intps', 2),
#  ('async', 2),
#  ('dyi', 2),
#  ('upwork', 2),
#  ('ocytocin', 2),
#  ('indianization', 2),
#  ('afcat', 2),
#  ('jvzoo', 2),
#  ('divs', 2),
#  ('binance', 2),
#  ('rotj', 2),
#  ('rnsit', 2),
#  ('mpsc', 2),
#  ('downvotes', 2),
#  ('kardashev', 2),
#  ('bittrex', 2),
#  ('displaystyle', 2),
#  ('selfie', 2),
#  ('cpec', 2),
#  ('fiverr', 2),
#  ('uchicago', 2),
#  ('regenepure', 2),
#  ('jaigaon', 2),
#  ('psycopath', 2),
#  ('mehanical', 2),
#  ('kavalireddi', 2),
#  ('argota', 2),
#  ('coep', 2),
#  ('pentene', 2),
#  ('suncream', 2),
#  ('coinbase', 2),
#  ('qty', 2),
#  ('manaphy', 2),
#  ('whatare', 2),
#  ('antifa', 2),
#  ('brexit', 2),
#  ('mainsprings', 2),
#  ('mobas', 2),
#  ('aadhar', 2),
#  ('myntra', 2),
#  ('capf', 2),
#  ('inorder', 2),
#  ('hackerrank', 2),
#  ('nicmar', 2),
#  ('chromecast', 1),
#  ('klv', 1),
#  ('midichlorians', 1),
#  ('abrahms', 1),
#  ('sjbit', 1),
#  ('nishita', 1),
#  ('biphobia', 1),
#  ('colligative', 1),
#  ('concumers', 1),
#  ('electroneum', 1),
#  ('spep', 1),
#  ('therw', 1),
#  ('commen', 1),
#  ('intercaste', 1),
#  ('erradicate', 1),
#  ('whatmotivates', 1),
#  ('pomerain', 1),
#  ('hypocritic', 1),
#  ('imediate', 1),
#  ('commensalism', 1),
#  ('svce', 1),
#  ('ccnp', 1),
#  ('mcse', 1),
#  ('mehendi', 1),
#  ('deptt', 1),
#  ('dhfl', 1),
#  ('mucoflux', 1),
#  ('nodet', 1),
#  ('sharedpreferences', 1),
#  ('sreeman', 1),
#  ('strrugle', 1),
#  ('nmol', 1),
#  ('milliunits', 1),
#  ('iitians', 1),
#  ('ransomware', 1),
#  ('entj', 1),
#  ('computor', 1),
#  ('concenterate', 1),
#  ('metabones', 1),
#  ('blackmagic', 1),
#  ('gitam', 1),
#  ('webtonist', 1),
#  ('entrepreuner', 1),
#  ('quoran', 1),
#  ('mealworm', 1),
#  ('coolnut', 1),
#  ('qbpos', 1),
#  ('yogasana', 1),
#  ('magento', 1),
#  ('accurs', 1),
#  ('octarine', 1),
#  ('ablus', 1),
#  ('lightworkers', 1),
#  ('trumpcare', 1),
#  ('mism', 1),
#  ('collge', 1),
#  ('mackmyra', 1),
#  ('onwer', 1),
#  ('barathiyar', 1),
#  ('khirokitia', 1),
#  ('suppor', 1),
#  ('circumsion', 1),
#  ('jeemains', 1),
#  ('chamge', 1),
#  ('drumpf', 1),
#  ('cervicocranial', 1),
#  ('xrp', 1),
#  ('mysogonist', 1),
#  ('muscluar', 1),
#  ('iqvia', 1),
#  ('stretegy', 1),
#  ('twad', 1),
#  ('dwarkadas', 1),
#  ('supercoiling', 1),
#  ('bacchan', 1),
#  ('oneplus', 1),
#  ('parsenallty', 1),
#  ('austrialia', 1),
#  ('comtroversial', 1),
#  ('walhberg', 1),
#  ('xrig', 1),
#  ('rmo', 1),
#  ('arround', 1),
#  ('ramk', 1),
#  ('endeca', 1),
#  ('sjws', 1),
#  ('thabu', 1),
#  ('organigram', 1),
#  ('austrolia', 1),
#  ('singapur', 1),
#  ('hootsuite', 1),
#  ('alggorithms', 1),
#  ('bramhin', 1),
#  ('xprab', 1),
#  ('parranoid', 1),
#  ('manglik', 1),
#  ('rajyog', 1),
#  ('pulikesi', 1),
#  ('millenials', 1),
#  ('additionals', 1),
#  ('friwend', 1),
#  ('tybcom', 1),
#  ('apear', 1),
#  ('zygomaticus', 1),
#  ('radiculopathy', 1),
#  ('foraminotomy', 1),
#  ('koushun', 1),
#  ('bcos', 1),
#  ('respone', 1),
#  ('zenfone', 1),
#  ('tvildiani', 1),
#  ('ἀριστοκράτης', 1),
#  ('bsod', 1),
#  ('gurugram', 1),
#  ('slected', 1),
#  ('descresaing', 1),
#  ('oppurtunities', 1),
#  ('npat', 1),
#  ('prolly', 1),
#  ('daca', 1),
#  ('tecnopark', 1),
#  ('skeptism', 1),
#  ('rautela', 1),
#  ('sdet', 1),
#  ('classses', 1),
#  ('pcthomas', 1),
#  ('autodidactism', 1),
#  ('khajida', 1),
#  ('howcan', 1),
#  ('reactjs', 1),
#  ('macramé', 1),
#  ('mongolese', 1),
#  ('quarash', 1),
#  ('expensiv', 1),
#  ('speedle', 1),
#  ('machedo', 1),
#  ('moval', 1),
#  ('sankri', 1),
#  ('irrelevate', 1),
#  ('unneglectable', 1),
#  ('diffrent', 1),
#  ('ngrx', 1),
#  ('muoet', 1),
#  ('rocksdb', 1),
#  ('blendy', 1),
#  ('sherria', 1),
#  ('tellitapes', 1),
#  ('catobolism', 1),
#  ('dmat', 1),
#  ('technopathy', 1),
#  ('gdpi', 1),
#  ('decolonizing', 1),
#  ('agrahari', 1),
#  ('nominalisation', 1),
#  ('someòne', 1),
#  ('bialetti', 1),
#  ('hardare', 1),
#  ('douchebaginess', 1),
#  ('douchebags', 1),
#  ('perfer', 1),
#  ('philosoper', 1),
#  ('youngters', 1),
#  ('xender', 1),
#  ('paradex', 1),
#  ('loat', 1),
#  ('gnaf', 1),
#  ('gnff', 1),
#  ('camcer', 1),
#  ('cholelithiasis', 1),
#  ('kresley', 1),
#  ('articleship', 1),
#  ('zerodha', 1),
#  ('kanthaka', 1),
#  ('sppu', 1),
#  ('tomatoe', 1),
#  ('overtg', 1),
#  ('clothess', 1),
#  ('effortfully', 1),
#  ('queffing', 1),
#  ('restraunts', 1),
#  ('deao', 1),
#  ('fhow', 1),
#  ('wingshan', 1),
#  ('combinatio', 1),
#  ('purrito', 1),
#  ('charachter', 1),
#  ('tindr', 1),
#  ('curriculars', 1),
#  ('abeeha', 1),
#  ('subjectie', 1),
#  ('culutre', 1),
#  ('batchmate', 1),
#  ('degee', 1),
#  ('alledges', 1),
#  ('ubersuggest', 1),
#  ('stoya', 1),
#  ('spagetti', 1),
#  ('fortnite', 1),
#  ('pakoṛā', 1),
#  ('microlearning', 1),
#  ('ossd', 1),
#  ('systen', 1),
#  ('vedios', 1),
#  ('excellant', 1),
#  ('jenar', 1),
#  ('syekh', 1),
#  ('ripublic', 1),
#  ('emmigrate', 1),
#  ('shopify', 1),
#  ('eej', 1),
#  ('الحجازية', 1),
#  ('ما', 1),
#  ('unrequest', 1),
#  ('fullfil', 1),
#  ('evisa', 1),
#  ('pragim', 1),
#  ('bookmyforex', 1),
#  ('plzz', 1),
#  ('ashwagandha', 1),
#  ('backlink', 1),
#  ('lgbtqi', 1),
#  ('sorghastrum', 1),
#  ('gerardii', 1),
#  ('coachings', 1),
#  ('dysuria', 1),
#  ('teegala', 1),
#  ('nishikido', 1),
#  ('scooty', 1),
#  ('bahaism', 1),
#  ('uniregistry', 1),
#  ('yhis', 1),
#  ('unsub', 1),
#  ('brzozowsky', 1),
#  ('schoola', 1),
#  ('recatangular', 1),
#  ('chashmah', 1),
#  ('ooltah', 1),
#  ('taarak', 1),
#  ('seduice', 1),
#  ('parineeti', 1),
#  ('maana', 1),
#  ('hennur', 1),
#  ('vuescan', 1),
#  ('temari', 1),
#  ('shikamaru', 1),
#  ('scatterplots', 1),
#  ('datapoints', 1),
#  ('donesnt', 1),
#  ('webstorm', 1),
#  ('masterbute', 1),
#  ('blackfyre', 1),
#  ('fustration', 1),
#  ('suvere', 1),
#  ('thermopro', 1),
#  ('secind', 1),
#  ('additons', 1),
#  ('paulinskill', 1),
#  ('utorrent', 1),
#  ('ggsipu', 1),
#  ('buoyance', 1),
#  ('grts', 1),
#  ('uitvoeren', 1),
#  ('betaling', 1),
#  ('masterbrates', 1),
#  ('philipian', 1),
#  ('unfollowed', 1),
#  ('csab', 1),
#  ('lanmarck', 1),
#  ('posulates', 1),
#  ('scoopinder', 1),
#  ('venemous', 1),
#  ('hyppothetical', 1),
#  ('reperations', 1),
#  ('pfrda', 1),
#  ('terorism', 1),
#  ('undicompose', 1),
#  ('wheather', 1),
#  ('cheatcodes', 1),
#  ('macports', 1),
#  ('hackings', 1),
#  ('iima', 1),
#  ('headcanons', 1),
#  ('neurolaw', 1),
#  ('mithali', 1),
#  ('tiquets', 1),
#  ('santioning', 1),
#  ('shooted', 1),
#  ('regenexx', 1),
#  ('digference', 1),
#  ('irodov', 1),
#  ('bengalurians', 1),
#  ('retrovisus', 1),
#  ('mookuthi', 1),
#  ('katuvas', 1),
#  ('importances', 1),
#  ('negativities', 1),
#  ('recognization', 1),
#  ('civillians', 1),
#  ('myparentstopursueeventmanagementasacareer', 1),
#  ('registr', 1),
#  ('criptocurrency', 1),
#  ('interviewbit', 1),
#  ('fleshgod', 1),
#  ('ryzen', 1),
#  ('striaght', 1),
#  ('applixant', 1),
#  ('blaketon', 1),
#  ('timr', 1),
#  ('tunesia', 1),
#  ('knw', 1),
#  ('transmetropolitan', 1),
#  ('nodejs', 1),
#  ('mssql', 1),
#  ('basicks', 1),
#  ('overconstraining', 1),
#  ('buissness', 1),
#  ('magoosh', 1),
#  ('patym', 1),
#  ('yularen', 1),
#  ('scomplishments', 1),
#  ('genuinly', 1),
#  ('threadbird', 1),
#  ('idfc', 1),
#  ('heitus', 1),
#  ('知识分子', 1),
#  ('universiyu', 1),
#  ('photograpy', 1),
#  ('cardistry', 1),
#  ('iift', 1),
#  ('allwoed', 1),
#  ('tabcoo', 1),
#  ('sporangiospore', 1),
#  ('kidness', 1),
#  ('preqin', 1),
#  ('qoute', 1),
#  ('pepole', 1),
#  ('roblox', 1),
#  ('stalins', 1),
#  ('peneration', 1),
#  ('whatapp', 1),
#  ('lallans', 1),
#  ('islamophobes', 1),
#  ('unberable', 1),
#  ('pyspark', 1),
#  ('udemy', 1),
#  ('restaraunt', 1),
#  ('shapefiles', 1),
#  ('adityanand', 1),
#  ('requirеd', 1),
#  ('jlbm', 1),
#  ('xxxtentacion', 1),
#  ('equivilent', 1),
#  ('evion', 1),
#  ('hypermasculinity', 1),
#  ('beaf', 1),
#  ('rupay', 1),
#  ('lodestones', 1),
#  ('sebjects', 1),
#  ('bcaf', 1),
#  ('pratyaya', 1),
#  ('powerbanks', 1),
#  ('verfication', 1),
#  ('wattpad', 1),
#  ('amercan', 1),
#  ('petreol', 1),
#  ('krzanichs', 1),
#  ('butatriene', 1),
#  ('malayisa', 1),
#  ('phythiotherapist', 1),
#  ('matpat', 1),
#  ('univdrsity', 1),
#  ('vesit', 1),
#  ('commucated', 1),
#  ('procus', 1),
#  ('traingulation', 1),
#  ('eyepower', 1),
#  ('beeteh', 1),
#  ('articlship', 1),
#  ('duckduckgo', 1),
#  ('jeop', 1),
#  ('edreams', 1),
#  ('citiscan', 1),
#  ('mediclaim', 1),
#  ('brigandine', 1),
#  ('ghiscari', 1),
#  ('stinkiest', 1),
#  ('blackpink', 1),
#  ('paystub', 1),
#  ('instacart', 1),
#  ('ailet', 1),
#  ('dillusional', 1),
#  ('recoilesss', 1),
#  ('backblast', 1),
#  ('solidier', 1),
#  ('codevita', 1),
#  ('ghoster', 1),
#  ('kansara', 1),
#  ('doiny', 1),
#  ('flarsky', 1),
#  ('psycology', 1),
#  ('citzen', 1),
#  ('endura', 1),
#  ('cumplen', 1),
#  ('enteros', 1),
#  ('existirá', 1),
#  ('relació', 1),
#  ('symbosis', 1),
#  ('danerys', 1),
#  ('suicidial', 1),
#  ('afib', 1),
#  ('eaadhaar', 1),
#  ('mempertanggungjawabkan', 1),
#  ('allometry', 1),
#  ('upwords', 1),
#  ('meaninglessly', 1),
#  ('falsley', 1),
#  ('reimburment', 1),
#  ('gazetteed', 1),
#  ('mitotane', 1),
#  ('offroll', 1),
#  ('hirogen', 1),
#  ('mahadasha', 1),
#  ('behcets', 1),
#  ('hanekawa', 1),
#  ('araragi', 1),
#  ('nekomonogatari', 1),
#  ('afganisthan', 1),
#  ('wmaf', 1),
#  ('tnpsc', 1),
#  ('amwf', 1),
#  ('vacumm', 1),
#  ('downloadtest', 1),
#  ('laakmann', 1),
#  ('elss', 1),
#  ('inequations', 1),
#  ('champak', 1),
#  ('analogus', 1),
#  ('opinons', 1),
#  ('desperatly', 1),
#  ('bieng', 1),
#  ('sybiote', 1),
#  ('botflies', 1),
#  ('regex', 1),
#  ('misbehaviours', 1),
#  ('ezymsg', 1),
#  ('missels', 1),
#  ('neonazism', 1),
#  ('muj', 1),
#  ('pgcet', 1),
#  ('downvoting', 1),
#  ('reffered', 1),
#  ('refrence', 1),
#  ('paraformaldehyde', 1),
#  ('excercising', 1),
#  ('conjuct', 1),
#  ('amcat', 1),
#  ('juristiction', 1),
#  ('vehetarian', 1),
#  ('ishare', 1),
#  ('esioniophils', 1),
#  ('apryl', 1),
#  ('marvadi', 1),
#  ('bromazepam', 1),
#  ('cocncrete', 1),
#  ('cocopeat', 1),
#  ('rastriyatavada', 1),
#  ('recitalent', 1),
#  ('ensquared', 1),
#  ('ouamuamua', 1),
#  ('tsavorite', 1),
#  ('appraoch', 1),
#  ('hostgator', 1),
#  ('theams', 1),
#  ('pabt', 1),
#  ('cpss', 1),
#  ('obor', 1),
#  ('iocl', 1),
#  ('flappy', 1),
#  ('socity', 1),
#  ('sigmaplot', 1),
#  ('mandalore', 1),
#  ('gsuite', 1),
#  ('americabs', 1),
#  ('viserys', 1),
#  ('flurishing', 1),
#  ('mediterean', 1),
#  ('depersonalised', 1),
#  ('sizeof', 1),
#  ('ringid', 1),
#  ('netlogon', 1),
#  ('ehyeh', 1),
#  ('vegito', 1),
#  ('iitd', 1),
#  ('antminer', 1),
#  ('chhenai', 1),
#  ('niilm', 1),
#  ('dsatm', 1),
#  ('genetal', 1),
#  ('vanker', 1),
#  ('bannned', 1),
#  ('kasatkina', 1),
#  ('zenly', 1),
#  ('minglewood', 1),
#  ('hydrometers', 1),
#  ('streat', 1),
#  ('phallen', 1),
#  ('kyc', 1),
#  ('clamper', 1),
#  ('wriite', 1),
#  ('jdd', 1),
#  ('pussified', 1),
#  ('mccaan', 1),
#  ('weightloss', 1),
#  ('obhects', 1),
#  ('fractionof', 1),
#  ('graphql', 1),
#  ('nullisomy', 1),
#  ('nmims', 1),
#  ('whice', 1),
#  ('aspie', 1),
#  ('nihonkai', 1),
#  ('tapentadol', 1),
#  ('involes', 1),
#  ('kingsman', 1),
#  ('trasfer', 1),
#  ('subinspector', 1),
#  ('kharidar', 1),
#  ('gtbit', 1),
#  ('strcpy', 1),
#  ('vbox', 1),
#  ('requirments', 1),
#  ('iranics', 1),
#  ('indics', 1),
#  ('qtb', 1),
#  ('gendry', 1),
#  ('howis', 1),
#  ('dizection', 1),
#  ('dowmward', 1),
#  ('niser', 1),
#  ('prophyria', 1),
#  ('mgtow', 1),
#  ('goodfriends', 1),
#  ('paytm', 1),
#  ('upgrad', 1),
#  ('phalgm', 1),
#  ('tumeric', 1),
#  ('pronoucation', 1),
#  ('redunction', 1),
#  ('molucular', 1),
#  ('bhm', 1),
#  ('enginerring', 1),
#  ('haloaranes', 1),
#  ('haloalkanes', 1),
#  ('simutaneously', 1),
#  ('goibibo', 1),
#  ('tilki', 1),
#  ('aleyna', 1),
#  ('platelats', 1),
#  ('voco', 1),
#  ('cosmograph', 1),
#  ('projest', 1),
#  ('agender', 1),
#  ('kokoretsi', 1),
#  ('intp', 1),
#  ('eluga', 1),
#  ('continuosly', 1),
#  ('inindia', 1),
#  ('antiglobalist', 1),
#  ('citenzhip', 1),
#  ('mukash', 1),
#  ('lebrons', 1),
#  ('stanking', 1),
#  ('aldiko', 1),
#  ('mktg', 1),
#  ('trazadone', 1),
#  ('asistant', 1),
#  ('fadnavis', 1),
#  ('trackimo', 1),
#  ('anerican', 1),
#  ('macpro', 1),
#  ('empaths', 1),
#  ('ammending', 1),
#  ('tazorac', 1),
#  ('bhakts', 1),
#  ('befool', 1),
#  ('lfcs', 1),
#  ('kgsp', 1),
#  ('emptyness', 1),
#  ('jacksfilms', 1),
#  ('explaination', 1),
#  ('contempurary', 1),
#  ('braavos', 1),
#  ('sanwaria', 1),
#  ('scool', 1),
#  ('comnerce', 1),
#  ('contagem', 1),
#  ('mumabi', 1),
#  ('ahemdabad', 1),
#  ('agroforest', 1),
#  ('ccondom', 1),
#  ('nofollow', 1),
#  ('jutti', 1),
#  ('thoery', 1),
#  ('serama', 1),
#  ('nonorbit', 1),
#  ('pubdet', 1),
#  ('emoji', 1),
#  ('pydata', 1),
#  ('aneides', 1),
#  ('reqiure', 1),
#  ('lehninger', 1),
#  ('mrmo', 1),
#  ('tannerite', 1),
#  ('plasanta', 1),
#  ('manipullate', 1),
#  ('iluminatti', 1),
#  ('ausbildung', 1),
#  ('turmoill', 1),
#  ('ustase', 1),
#  ('katalon', 1),
#  ('epidata', 1),
#  ('imessage', 1),
#  ('indivudal', 1),
#  ('boobed', 1),
#  ('tsllest', 1),
#  ('probablity', 1),
#  ('diging', 1),
#  ('cambogia', 1),
#  ('machins', 1),
#  ('dolpo', 1),
#  ('bpsc', 1),
#  ('milimetre', 1),
#  ('enironment', 1),
#  ('eddition', 1),
#  ('dimensons', 1),
#  ('reasing', 1),
#  ('quesyio', 1),
#  ('mucociliary', 1),
#  ('kalistan', 1),
#  ('movments', 1),
#  ('choosen', 1),
#  ('ravula', 1),
#  ('ravindrababu', 1),
#  ('devided', 1),
#  ('viibryd', 1),
#  ('cyoa', 1),
#  ('hernadez', 1),
#  ('thucydiean', 1),
#  ('cocksucker', 1),
#  ('thordis', 1),
#  ('milsims', 1),
#  ('extinguiches', 1),
#  ('howmany', 1),
#  ('dragonaut', 1),
#  ('nawazuddin', 1),
#  ('virali', 1),
#  ('msrit', 1),
#  ('mixnine', 1),
#  ('smule', 1),
#  ('qiteng', 1),
#  ('anlytics', 1),
#  ('perfectible', 1),
#  ('erso', 1),
#  ('manstruate', 1),
#  ('unattainably', 1),
#  ('preparartion', 1),
#  ('uːn', 1),
#  ('dʒəʊŋ', 1),
#  ('kɪm', 1),
#  ('bemer', 1),
#  ('aipmt', 1),
#  ('pakijiang', 1),
#  ('emporer', 1),
#  ('indangered', 1),
#  ('abhyanand', 1),
#  ('syzigium', 1),
#  ('libgdx', 1),
#  ('pendrive', 1),
#  ('porns', 1),
#  ('inteligent', 1),
#  ('kundli', 1),
#  ('sgpa', 1),
#  ('intracompany', 1),
#  ('arrowverse', 1),
#  ('mbbbs', 1),
#  ('iitjee', 1),
#  ('namkai', 1),
#  ('keyholder', 1),
#  ('benificial', 1),
#  ('funiture', 1),
#  ('deplorables', 1),
#  ('libtard', 1),
#  ('ndia', 1),
#  ('bookrenter', 1),
#  ('dialogflow', 1),
#  ('airpod', 1),
#  ('shrinidhi', 1),
#  ('lodamee', 1),
#  ('illinoise', 1),
#  ('apexdrop', 1),
#  ('aprroach', 1),
#  ('geonosian', 1),
#  ('nantex', 1),
#  ('kailani', 1),
#  ('hariot', 1),
#  ('sraddha', 1),
#  ('rubrik', 1),
#  ('unautomized', 1),
#  ('madheshis', 1),
#  ('skyrim', 1),
#  ('trillionares', 1),
#  ('hostle', 1),
#  ('worshopping', 1),
#  ('audrino', 1),
#  ('anayat', 1),
#  ('flipchart', 1),
#  ('phunetsholing', 1),
#  ('godwho', 1),
#  ('physiocare', 1),
#  ('unsignificant', 1),
#  ('neurotypical', 1),
#  ('btween', 1),
#  ('fireing', 1),
#  ('ldaxb', 1),
#  ('woodbe', 1),
#  ('akabar', 1),
#  ('allauah', 1),
#  ('mangghystaū', 1),
#  ('pixma', 1),
#  ('videoke', 1),
#  ('sharingan', 1),
#  ('fintech', 1),
#  ('bioprinter', 1),
#  ('pesit', 1),
#  ('eternalism', 1),
#  ('autopay', 1),
#  ('engineern', 1),
#  ('awdhesh', 1),
#  ('hermoine', 1),
#  ('blueair', 1),
#  ('moolla', 1),
#  ('cosigners', 1),
#  ('vámbéry', 1),
#  ('ármin', 1),
#  ('clarium', 1),
#  ('mechanica', 1),
#  ('masterdetail', 1),
#  ('vayner', 1),
#  ('byjus', 1),
#  ('bhavisja', 1),
#  ('hpw', 1),
#  ('ifttt', 1),
#  ('thiefs', 1),
#  ('pseudofeminism', 1),
#  ('launchora', 1),
#  ('aliexpress', 1),
#  ('xlint', 1),
#  ('creampie', 1),
#  ('characterictic', 1),
#  ('quoraa', 1),
#  ('lmrc', 1),
#  ('chitkara', 1),
#  ('venderkam', 1),
#  ('palpans', 1),
#  ('preffered', 1),
#  ('menstruations', 1),
#  ('pregnent', 1),
#  ('mpos', 1),
#  ('hybird', 1),
#  ('jewelleries', 1),
#  ('drauzen', 1),
#  ('takedownmilliebobbybrown', 1),
#  ('solovar', 1),
#  ('pimpls', 1),
#  ('cocern', 1),
#  ('benifisial', 1),
#  ('otsutsuki', 1),
#  ('pshychologists', 1),
#  ('exageration', 1),
#  ('srmjeee', 1),
#  ('nazeem', 1),
#  ('mbaas', 1),
#  ('shareasale', 1),
#  ('acceleraton', 1),
#  ('quantative', 1),
#  ('alureon', 1),
#  ('iimb', 1),
#  ('thene', 1),
#  ('bewafa', 1),
#  ('newblom', 1),
#  ('cource', 1),
#  ('islams', 1),
#  ('dmlt', 1),
#  ('bmlt', 1),
#  ('gorakpur', 1),
#  ('iiith', 1),
#  ('bitsh', 1),
#  ('predant', 1),
#  ('restructurations', 1),
#  ('trolly', 1),
#  ('enterpreneur', 1),
#  ('zelandia', 1),
#  ('pewdiepie', 1),
#  ('reall', 1),
#  ('fiitjee', 1),
#  ('shorlisted', 1),
#  ('gravol', 1),
#  ('vasograin', 1),
#  ('esay', 1),
#  ('doeden', 1),
#  ('timesup', 1),
#  ('alshami', 1),
#  ('isit', 1),
#  ('protectee', 1),
#  ('irfaan', 1),
#  ('costimulation', 1),
#  ('narisa', 1),
#  ('stereoblindness', 1),
#  ('infp', 1),
#  ('masterbating', 1),
#  ('diffrence', 1),
#  ('sciencetific', 1),
#  ('netfli', 1),
#  ('constitunital', 1),
#  ('dushka', 1),
#  ('nouse', 1),
#  ('kanchanjunga', 1),
#  ('thinging', 1),
#  ('sinchan', 1),
#  ('memrise', 1),
#  ('kvpy', 1),
#  ('bablyonians', 1),
#  ('carplay', 1),
#  ('whatis', 1),
#  ('apatheist', 1),
#  ('wiskey', 1),
#  ('knoe', 1),
#  ('agancies', 1),
#  ('proxified', 1),
#  ('iswarya', 1),
#  ('colestrol', 1),
#  ('lumineer', 1),
#  ('kpca', 1),
#  ('warfares', 1),
#  ('echogenicity', 1),
#  ('updation', 1),
#  ('aadhaar', 1),
#  ('emphathy', 1),
#  ('uceed', 1),
#  ('dicresing', 1),
#  ('aspies', 1),
#  ('simco', 1),
#  ('nlh', 1),
#  ('valak', 1),
#  ('posdoctoral', 1),
#  ('virtualdub', 1),
#  ('austrailia', 1),
#  ('austrailians', 1),
#  ('makibg', 1),
#  ('pneumatonometers', 1),
#  ('coprophilia', 1),
#  ('goolgappa', 1),
#  ('icseformat', 1),
#  ('trumpsters', 1),
#  ('initals', 1),
#  ('fualts', 1),
#  ('gstr', 1),
#  ('sybols', 1),
#  ('lithogenous', 1),
#  ('tsundere', 1),
#  ('habbit', 1),
#  ('turds', 1),
#  ('belmod', 1),
#  ('icancelledmytriptolondon', 1),
#  ('modere', 1),
#  ('karumaari', 1),
#  ('keygen', 1),
#  ('differnces', 1),
#  ('abdominoplasty', 1),
#  ('musinipally', 1),
#  ('ustilago', 1),
#  ('dhals', 1),
#  ('laravel', 1),
#  ('psychogeometry', 1),
#  ('durelli', 1),
#  ('havenrock', 1),
#  ('turkménistan', 1),
#  ('sarkeesian', 1),
#  ('aurini', 1),
#  ('nutjob', 1),
#  ('dualists', 1),
#  ('panchkarma', 1)]

# %% [markdown]
# (OPTIONAL)
# How to improve this rate:
# * Should we remove punctuation ?
# * Should we remove numbers ?
# * Should we remove stopwords ?
# * Should we Stemmatize / Lemmatize ?
#
# We could also use TextBlob for mispellings

# %%
#Compute the embedding for each question text from word embeddings
def get_vector_from(tokens):
    word_vect = np.array([word_to_vec_map[t] for t in tokens if t in words])
    try: 
        word_vect = word_vect.mean(axis = 0).astype("float64")
    except:
        print("Can not convert tokens into vector")
    return word_vect

# %%
df_sample["vector"] = df_sample["tokens"].apply(lambda x : get_vector_from(x))
df_sample.head()
# Out:
#                           qid  \
# 1306057  fffcc30ffad59abeb37c
# 1054851  ceb482134d2febdf1ca9
# 458916   59e38ecfecac0d30ff17
# 777189   983ba415e1b49aa501ef
# 106550   14df3cd54d22e3f7d989
#
#                                                                                                                  question_text  \
# 1306057                                                                                Can profanity make you have bad breath?
# 1054851                                                                       What is the scope of food microbiology in India?
# 458916                                                                                   What is the Maharashtrian Panchkarma?
# 777189                                                          What's the best alternative to Craigslist's casual encounters?
# 106550   Do left-leaning parties mostly win in the U.K. and the E.U. because of the voting rights extended to most immigrants?
#
#          target  \
# 1306057       0
# 1054851       0
# 458916        0
# 777189        0
# 106550        1
#
#                                                                                                                                  tokens  \
# 1306057                                                                                  [can, profanity, make, you, have, bad, breath]
# 1054851                                                                       [what, is, the, scope, of, food, microbiology, in, india]
# 458916                                                                                       [what, is, the, maharashtrian, panchkarma]
# 777189                                                         [what, s, the, best, alternative, to, craigslist, s, casual, encounters]
# 106550   [do, left, leaning, parties, mostly, win, in, the, and, the, because, of, the, voting, rights, extended, to, most, immigrants]
#
#                                                                       tokens_no_stop  \
# 1306057                                               [profanity, make, bad, breath]
# 1054851                                           [scope, food, microbiology, india]
# 458916                                                   [maharashtrian, panchkarma]
# 777189                           [best, alternative, craigslist, casual, encounters]
# 106550   [left, leaning, parties, mostly, win, voting, rights, extended, immigrants]
#
#                                                                       lemmatized  \
# 1306057                                           [profanity, make, bad, breath]
# 1054851                                       [scope, food, microbiology, india]
# 458916                                               [maharashtrian, panchkarma]
# 777189                        [best, alternative, craigslist, casual, encounter]
# 106550   [left, leaning, party, mostly, win, voting, right, extended, immigrant]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           vector
# 1306057  [0.2735097285714286, 0.05876699999999997, 0.056122857142857155, -0.375049, 0.0704845142857143, 0.15373485714285712, 0.017307428571428547, -0.015300399999999976, -0.08001171428571427, 0.5773367142857143, -0.1778442857142857, 0.5031191428571429, -0.04093857142857145, 0.026195285714285716, 0.7030200000000002, 0.35897428571428575, 0.10021428571428574, -0.01711428571428571, -0.1063357142857143, -0.9463, -0.34211299999999994, 0.34108171428571427, 0.8415585714285714, 0.2369317142857143, 0.4061657142857143, -1.4598014285714285, -0.5350414285714286, 0.4181371428571429, 0.8740585714285712, -0.5098187142857143, 3.0746428571428575, 0.6231571428571429, -0.19968942857142857, -0.33182042857142857, 0.005309999999999997, 0.143164, 0.1407133857142857, -0.1728361428571428, 0.2896671428571428, -0.36075552857142856, 0.03326571428571429, 0.3396215714285714, 0.012548571428571418, 0.67879, 0.28333142857142857, 0.3194828571428571, 0.1407157142857143, 0.18043328571428568, -0.010018999999999986, 0.3801571428...
# 1054851  [0.26735222222222227, 0.1263556666666667, -0.4713877777777778, 0.12336433333333334, 0.38066144444444444, 0.1495381111111111, -0.05365067777777781, -0.45607711111111104, 0.522403641111111, -0.20170766666666667, 0.17037688888888888, -0.09953077777777777, -0.1056943333333333, -0.34298, 0.19559116666666668, 0.3171564688888889, 0.15637926666666668, 0.16883233333333333, -0.2752677777777778, -0.00864044444444445, 0.31375322222222224, 0.025500888888888896, 0.13465855555555553, -0.08030177777777779, 0.09772866666666667, -1.5335244444444445, -0.5496866666666667, -0.02418655555555555, -0.08116377777777777, 0.06215588888888887, 3.0917703333333337, -0.04429, -0.19633677777777775, -0.5331522222222221, 0.010794125555555553, -0.051371522222222216, -0.19677566666666665, 0.262649, 0.16964566666666667, 0.11761744444444444, -0.27918511111111116, 0.06670253333333333, 0.10599711111111111, 0.009764666666666692, -0.059343333333333276, 0.41201999999999994, -0.00021323333333334027, 0.1760566666666667, 0.004...
# 458916                                                                                                                                                                                                                               [0.4911175, 0.14684275, -0.7289025, -0.002835000000000011, 0.5833625, 0.31701325, -0.18990652500000002, -0.12743625000000003, -0.2273625575, -0.022062499999999992, 0.154975, 0.009442499999999993, 0.05002774999999998, 0.008412500000000031, 0.310776375, 0.200337, 0.22200999999999999, 0.32897999999999994, -0.1579, -0.07375499999999997, -0.29808775, -0.09314, -0.263776, 0.4692765, 0.2922925, -1.4767825, -0.7988175000000001, 0.21444525, 0.05886150000000001, -0.15591100000000002, 2.6559725000000003, -0.009847500000000009, -0.21625999999999995, -0.201905, -0.026730717499999994, -0.121178775, -0.09519, -0.03971925, 0.04669275, 0.003631750000000003, -0.25042575, 0.1369925, -0.22264450000000002, 0.211798, -0.140708, 0.22685999999999998, -0.132297275, 0.06205, 0.1790175, 0.04411]
# 777189                                                                                                                                               [0.26287000000000005, 0.24856470000000003, -0.05383500000000001, 0.2535116, 0.37770000000000004, 0.10803951, -0.369654, -0.2999075, 0.099873177, 0.20097199999999998, -0.1618011, 0.03411259999999999, -0.277228, 0.0389016, 0.37124405, -0.011123100000000007, -0.08957260000000002, -0.11411669999999999, -0.24060699999999996, -0.3232131, 0.0831878, 0.2526446, -0.03518800000000001, 0.42797100000000005, 0.10403100000000001, -1.192477, -0.4633010000000001, -0.08083470000000001, 0.22203499999999998, -0.1351104, 2.515914, 0.10661400000000001, -0.30100866600000004, -0.18184399999999998, 0.03959891299999999, -0.286501429, -0.0841674, -0.1339672, -0.3354867, -0.4263293000000001, 0.153457, -0.03991760000000001, -0.0013958500000000027, 0.2794663, 0.06239179999999998, -0.0013390999999999763, 0.10113608999999998, 0.034419899999999996, 0.26385169999999997, 0.315264]
# 106550   [0.16921894736842105, 0.040345473684210514, -0.09927273684210525, -0.08561805263157896, 0.19972473684210526, 0.2122246315789474, -0.48332221052631585, 0.055205473684210554, -0.28147698368421054, -0.14968936842105263, -0.0028764105263157764, -0.34974242105263154, -0.15371484210526323, -0.02815231578947367, 0.23334671052631578, -0.0033001052631578967, 0.1637976842105263, -0.2856836157894737, -0.21952210526315788, -0.3368117894736843, -0.05661942105263157, 0.051310810526315795, 0.13674094736842102, 0.12000321052631578, -0.04337121052631581, -1.557054210526316, -0.2516126368421053, -0.12944405263157893, -0.011500894736842106, -0.12386026315789471, 3.3999894736842107, 0.26771911578947366, -0.4143708947368421, -0.44870905263157895, -0.09155924263157894, -0.16445562631578942, -0.06166684210526313, 0.07429142105263159, -0.11561926315789472, -0.062279736842105256, -0.34679715789473686, 0.048625125789473686, 0.08223668421052632, 0.22430173684210525, -0.3311406842105263, 0.0907856263157895, -...

# %%
X = df_sample.vector.apply(lambda x : pd.Series(x))
X = X.set_index(df_sample.index)
X.head()
# Out:
#                0         1         2         3         4         5         6   \
# 1306057  0.273510  0.058767  0.056123 -0.375049  0.070485  0.153735  0.017307
# 1054851  0.267352  0.126356 -0.471388  0.123364  0.380661  0.149538 -0.053651
# 458916   0.491117  0.146843 -0.728903 -0.002835  0.583363  0.317013 -0.189907
# 777189   0.262870  0.248565 -0.053835  0.253512  0.377700  0.108040 -0.369654
# 106550   0.169219  0.040345 -0.099273 -0.085618  0.199725  0.212225 -0.483322
#
#                7         8         9   ...        40        41        42  \
# 1306057 -0.015300 -0.080012  0.577337  ...  0.033266  0.339622  0.012549
# 1054851 -0.456077  0.522404 -0.201708  ... -0.279185  0.066703  0.105997
# 458916  -0.127436 -0.227363 -0.022062  ... -0.250426  0.136992 -0.222645
# 777189  -0.299907  0.099873  0.200972  ...  0.153457 -0.039918 -0.001396
# 106550   0.055205 -0.281477 -0.149689  ... -0.346797  0.048625  0.082237
#
#                43        44        45        46        47        48        49
# 1306057  0.678790  0.283331  0.319483  0.140716  0.180433 -0.010019  0.380157
# 1054851  0.009765 -0.059343  0.412020 -0.000213  0.176057  0.004581 -0.165927
# 458916   0.211798 -0.140708  0.226860 -0.132297  0.062050  0.179017  0.044110
# 777189   0.279466  0.062392 -0.001339  0.101136  0.034420  0.263852  0.315264
# 106550   0.224302 -0.331141  0.090786 -0.420932 -0.123158 -0.030519 -0.393429
#
# [5 rows x 50 columns]

# %%
y = df_sample.target
y.head()
# Out:
# 1306057    0
# 1054851    0
# 458916     0
# 777189     0
# 106550     1
# Name: target, dtype: int64

# %%
df_new = pd.concat([X, y], axis=1)
df_new = df_new.dropna()

# %% [markdown]
# ## ML model

# %%
y = df_new.target
X = df_new.drop("target", axis=1)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# TODO: Train the model
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# TODO Estimate the accuracy
y_pred = lr.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      1886
#            1       0.48      0.13      0.21       114
#
#     accuracy                           0.94      2000
#    macro avg       0.72      0.56      0.59      2000
# weighted avg       0.92      0.94      0.93      2000

# %% [markdown]
# ## Can you explain why the performance for class 1 (insincere questions) is bad? Can we improve?

# %%
#Only simple model with some missed vocabulary, improve preprocessing
#Try multiple algorithms
